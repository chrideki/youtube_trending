# %% [markdown]
# source: https://www.kaggle.com/hoonkeng/deep-analysis-on-youtube-trending-videos-eda/notebook

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
filename1 = 'dataframe.csv'
filename2 = 'dataframe_all_timestamps.csv'

df = pd.read_csv('../youtube/dataframe.csv')
df_all_timestamps = pd.read_csv('../youtube/dataframe_all_timestamps.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171149 entries, 0 to 171148
# Data columns (total 19 columns):
# video_id                  171149 non-null object
# trending_date             171149 non-null object
# title                     171149 non-null object
# channel_title             171149 non-null object
# category_id               171149 non-null int64
# category                  171149 non-null object
# publish_date              171149 non-null object
# publish_time              171149 non-null object
# tags                      171149 non-null object
# views                     171149 non-null int64
# likes                     171149 non-null int64
# dislikes                  171149 non-null int64
# comment_count             171149 non-null int64
# thumbnail_link            171149 non-null object
# comments_disabled         171149 non-null bool
# ratings_disabled          171149 non-null bool
# video_error_or_removed    171149 non-null bool
# description               171149 non-null object
# country                   171149 non-null object
# dtypes: bool(3), int64(5), object(11)
# memory usage: 21.4+ MB

# %%
df_all_timestamps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356350 entries, 0 to 356349
# Data columns (total 19 columns):
# video_id                  356350 non-null object
# trending_date             356350 non-null object
# title                     356350 non-null object
# channel_title             356350 non-null object
# category_id               356350 non-null int64
# category                  356350 non-null object
# publish_date              356350 non-null object
# publish_time              356350 non-null object
# tags                      356350 non-null object
# views                     356350 non-null int64
# likes                     356350 non-null int64
# dislikes                  356350 non-null int64
# comment_count             356350 non-null int64
# thumbnail_link            356350 non-null object
# comments_disabled         356350 non-null bool
# ratings_disabled          356350 non-null bool
# video_error_or_removed    356350 non-null bool
# description               356350 non-null object
# country                   356350 non-null object
# dtypes: bool(3), int64(5), object(11)
# memory usage: 44.5+ MB

# %%
def stringify(row):
    return str(row['publish_date']) + ' ' + str(row['publish_time'])

df_all_timestamps.loc[:,'string_date_time'] = \
                            df_all_timestamps.apply(stringify, axis=1)

df_all_timestamps.loc[:,'publish_timestamp'] = \
                pd.to_datetime(df_all_timestamps['string_date_time'],
                                infer_datetime_format=True,
                                errors='coerce')

df_all_timestamps = df_all_timestamps.drop('string_date_time', axis=1)

#make a new column in df called 'publish_timestamp' 
#that is a datetime object

df.loc[:,'string_date_time'] = df.apply(stringify, axis=1)
df.loc[:,'publish_timestamp'] = \
                pd.to_datetime(df['string_date_time'],
                                infer_datetime_format=True,
                                errors='coerce')
df = df.drop('string_date_time', axis=1)

# %%
def stringifybis(row):
    return str(row['trending_date'])

df_all_timestamps.loc[:,'string_date_time'] = \
                            df_all_timestamps.apply(stringifybis, axis=1)

df_all_timestamps.loc[:,'trending_timestamp'] = \
                pd.to_datetime(df_all_timestamps['string_date_time'],
                                infer_datetime_format=True,
                                errors='coerce')

df_all_timestamps = df_all_timestamps.drop('string_date_time', axis=1)

# %%
df_all_timestamps[['title', 'views', 'country', 'trending_date']].sort_values('views', ascending = False).head(10)
# Out:
#                                                     title      views country  \
# 245305  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  424538912      GB
# 243642  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  413586699      GB
# 240603  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  402650804      GB
# 239722  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  392036878      GB
# 236698  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  382401497      GB
# 235400  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  372399338      GB
# 234431  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  362111555      GB
# 231508  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  349987176      GB
# 229579  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  339629489      GB
# 306688  Te Bote Remix - Casper, Nio García, Darell, Ni...  337621571      GB
#
#        trending_date
# 245305    2018-04-07
# 243642    2018-04-06
# 240603    2018-04-05
# 239722    2018-04-04
# 236698    2018-04-03
# 235400    2018-04-02
# 234431    2018-04-01
# 231508    2018-03-31
# 229579    2018-03-30
# 306688    2018-05-18

# %%
df[['title', 'views', 'country', 'publish_date']].sort_values('views', ascending = False).head(10)
# Out:
#                                                     title      views country  \
# 119441  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  424538912      GB
# 149316  Te Bote Remix - Casper, Nio García, Darell, Ni...  337621571      GB
# 105767               Bad Bunny - Amorfoda | Video Oficial  328860380      GB
# 86795            Ozuna x Romeo Santos - El Farsante Remix  288811992      GB
# 167397  Childish Gambino - This Is America (Official V...  259721696      GB
# 107307                                 Drake - God’s Plan  258164991      GB
# 155749               Ariana Grande - No Tears Left To Cry  208876887      GB
# 155748  Becky G, Natti Natasha - Sin Pijama (Official ...  200862743      GB
# 32380   YouTube Rewind: The Shape of 2017 | #YouTubeRe...  169884583      GB
# 73848                 Dura - Daddy Yankee (Video Oficial)  167456025      GB
#
#        publish_date
# 119441   2018-03-02
# 149316   2018-04-11
# 105767   2018-02-15
# 86795    2018-01-30
# 167397   2018-05-06
# 107307   2018-02-17
# 155749   2018-04-20
# 155748   2018-04-20
# 32380    2017-12-06
# 73848    2018-01-18

# %%
df[df['country'] == 'US'][['title', 'country', 'views', 'trending_date']].sort_values('views', ascending = False).head(10)
# Out:
#                                                     title country     views  \
# 107016              Maluma - El Préstamo (Official Video)      US  87264467
# 146563                      VENOM - Official Trailer (HD)      US  59254638
# 166508           Selena Gomez - Back To You (Lyric Video)      US  54863912
# 22112    42 HOLY GRAIL HACKS THAT WILL SAVE YOU A FORTUNE      US  54155921
# 146586  Sanju | Official Teaser | Ranbir Kapoor | Rajk...      US  48654951
# 159668  Do You Hear Yanny or Laurel? (SOLVED with SCIE...      US  42799458
# 169801               Daddy Yankee - Hielo (Video Oficial)      US  41803845
# 125236     The Weeknd - Call Out My Name (Official Audio)      US  41604561
# 146540        Jennifer Lopez - El Anillo (Official Video)      US  41446137
# 169825  Sanju | Official Trailer | Ranbir Kapoor | Raj...      US  40714581
#
#        trending_date
# 107016    2018-03-25
# 146563    2018-05-14
# 166508    2018-06-09
# 22112     2017-12-11
# 146586    2018-05-14
# 159668    2018-06-01
# 169801    2018-06-14
# 125236    2018-04-20
# 146540    2018-05-14
# 169825    2018-06-14

# %%
# how to subset the minimum date for each video, to check which has the best impact on the audience
# first_collection = df_all_timestamps.groupby(['title'])['trending_timestamp'].min().head()
# first_collection

# %%
df.category.describe()
# Out:
# count            171149
# unique               18
# top       Entertainment
# freq              50468
# Name: category, dtype: object

# %%
df1 = df.groupby(['category']).agg({'views':['sum']})
df1 = df1.sort_values(('views', 'sum'), ascending = False)
df1 = df1.reset_index()
fig = plt.figure(figsize=(8,6)) 
ax = fig.gca()
sns.barplot(x = 'category', y = ('views', 'sum'), data = df1)
plt.xticks(rotation=90)
ax.set_title('Total views per category')
# Out:
# Text(0.5, 1.0, 'Total views per category')

# %%
df2 = df.groupby(['country', 'category']).agg({'views':['sum']}).sort_values(['country',('views', 'sum')],ascending=False)
# df2 = f.nlargest(3)
# df2 = df2.reset_index()
df2 = df2.groupby('country').head(3)
df2 = df2.reset_index()
sns.set(style="ticks")
g = sns.FacetGrid(df2, col = ('country', ''), col_wrap= 5, height = 4)
g.map(sns.barplot, ('category', '' ), ('views', 'sum'), palette = 'Set2')

# %%
df2
# Out:
#    country          category        views
#                                       sum
# 0       US     Entertainment   1734609517
# 1       US             Music   1341970959
# 2       US            Comedy    593769145
# 3       RU     Entertainment   1020230986
# 4       RU    People & Blogs    832798537
# 5       RU            Comedy    524030047
# 6       MX     Entertainment   1657854765
# 7       MX             Music    673111808
# 8       MX    People & Blogs    568068035
# 9       KR     Entertainment   1090038619
# 10      KR    People & Blogs    487540735
# 11      KR   News & Politics    417885411
# 12      JP     Entertainment    537172141
# 13      JP    People & Blogs    190997162
# 14      JP            Sports    160120939
# 15      IN     Entertainment   3186553856
# 16      IN             Music   1997846460
# 17      IN   News & Politics    706432082
# 18      GB             Music  11320665997
# 19      GB     Entertainment   1966902816
# 20      GB  Film & Animation    427891387
# 21      FR     Entertainment    869764606
# 22      FR            Sports    569844050
# 23      FR            Comedy    535343676
# 24      DE     Entertainment   2049012545
# 25      DE    People & Blogs    606500574
# 26      DE            Sports    428391087
# 27      CA     Entertainment   3105798985
# 28      CA             Music   1119539801
# 29      CA    People & Blogs    834458545

# %%
## df.groupby(['category']).agg({'views':['sum'], 'video_id':['count'] }).head()

# %%
first_collection = df_all_timestamps.groupby(['title']).agg({'trending_timestamp':['min']}).head()

# %%
first_collection
# Out:
#                                                    trending_timestamp
#                                                                   min
# title
#  Désolé je ne vous avais pas vu !  😱 👎 ✶ DO 65             2018-01-18
#  Es admirable que Shani haya tenido agallas par...         2018-02-02
#  Fantasma, no necesitabas traer a tus achichinc...         2018-03-09
#  KAJAL RAGHWANI  SUPERHIT MOVIE ( Full HD 2018 ...         2017-12-31
#  Me La Jugué con Riesgo a Tronarme Así Habló Lu...         2018-05-11

# %%
df_all_timestamps.loc[df_all_timestamps['trending_timestamp'].idxmax()]
# Out:
# video_id                                                        sBMOXHrXJtI
# trending_date                                                    2018-06-14
# title                     Cuphead DLC Announcement Trailer | Xbox One | ...
# channel_title                                                   Studio MDHR
# category_id                                                              20
# category                                                             Gaming
# publish_date                                                     2018-06-10
# publish_time                                                       21:14:22
# tags                                                                 [none]
# views                                                               1608741
# likes                                                                 72970
# dislikes                                                                763
# comment_count                                                         15445
# thumbnail_link               https://i.ytimg.com/vi/sBMOXHrXJtI/default.jpg
# comments_disabled                                                     False
# ratings_disabled                                                      False
# video_error_or_removed                                                False
# description               In Cuphead: The Delicious Last Course, Cuphead...
# country                                                                  US
# publish_timestamp                                       2018-06-10 21:14:22
# trending_timestamp                                      2018-06-14 00:00:00
# Name: 354613, dtype: object
