# %% [markdown]
# # Visualization with Python, Project 1
#
# In this project I'm going to analyze a dataset which includes data about trending video on YouTube. Here's the data source: https://www.kaggle.com/hoonkeng/deep-analysis-on-youtube-trending-videos-eda/notebook
#
# In the dataset, collected across 10 countries, we find information about views, video descriptions, title, category, tag, number of like, dislikes, comments.
# Two versions of the dataset are available: in the first one there is one global collection; in the second we have more collection from 2017 to 2018.
#
# My analysis will have two parts:
# 1. an overview of the data, with some general observations
# 2. focus on some relevant aspect for the YouTube user

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
filename1 = 'dataframe.csv'
filename2 = 'dataframe_all_timestamps.csv'

df = pd.read_csv('../dataframe.csv')
df_all_timestamps = pd.read_csv('../dataframe_all_timestamps.csv')

# %% [markdown]
# ## Part 1. Overview
#
# ### What do people post on Youtube?
# In the next plot we find the number of videos uploaded in every category.
# Entertainment results clearly the first category, followed by Peolple & Blogs and News & Politics.

# %%
df1 = df.groupby(['category']).agg({'video_id':['count']})
df1 = df1.sort_values(('video_id', 'count'), ascending = False)
df1 = df1.reset_index()
fig = plt.figure(figsize=(8,6)) 
ax = fig.gca()
sns.barplot(x = 'category', y = ('video_id', 'count'), data = df1)
plt.xticks(rotation=90)
sns.set(font_scale=1.5)
ax.set_title('Number of video by category')
# Out:
# Text(0.5, 1.0, 'Number of video by category')

# %% [markdown]
# ## A pie chart...
# With a pie chart we obtain a different visualization of the same data. The pie highligths the percentages. So we notice that one third of the contents on YouTube is Entertainment.
# Since the version of the pie with all categories was overloaded with tags and labels, I have dediced to make a new tidy pie. So that I wrote a function, adding up the last nine categories in a new category called 'others'. Now the pie results more readable.

# %%
def other_in_pie(size, label):
    new_size = []
    new_label = []
    other = 0
    for i in range(len(size)):
        if i in range(0,9):
            new_size.append(size[i])
            new_label.append(label[i])
        else: other += size[i]
    new_size.append(other)
    new_label.append('others')
    return new_size, new_label

# %%
df_for_pie = df1
my_circle = plt.Circle( (0,0), 0.5, color='white')
size = df_for_pie[('video_id', 'count')]
labels = df_for_pie['category']
fig = plt.figure(figsize=(10,10)) 
ax1 = fig.gca()
new_size = other_in_pie(size, labels)[0]
new_label = other_in_pie(size, labels)[1]
ax1.pie(new_size, labels = new_label, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## What do people actually watch on Youtube?
# When it comes to visualizations, we obtain a different order and at the first place we find Music. Entertainment and People & Blog are in second and third position.

# %%
df_per_category = df.groupby(['category']).agg({'views':['sum']})
df_per_category = df_per_category.sort_values(('views', 'sum'), ascending = False)
df_per_category = df_per_category.reset_index()
fig = plt.figure(figsize=(8,6)) 
ax = fig.gca()
sns.barplot(x = 'category', y = ('views', 'sum'), data = df_per_category)
plt.xticks(rotation=90)
sns.set(font_scale=1.5)
ax.set_title('Total views per category')
# Out:
# Text(0.5, 1.0, 'Total views per category')

# %% [markdown]
# ## A look across the countries...
# In the next heatmap I intersect category data and country to find the number of views for every category in every country. A heatmap is a graph where color and nuances indicate the difference between the values. I've used a scale from red to blue where the darker is the red the lower is the value, and the darker is the blue the bigger is the number of views.
# The first version of the heatmap is not really helpful because of the big distance from the number of visualizations of musical videos in Great Britain and the rest of the data. So I've chosen to visualize all data but those of Great Britain. Then I've made a function to add the ranking of each category in every country.

# %%
heat_view_data = df.groupby(['country', 'category']).agg({'views':['sum']})
heat_view_data = pd.pivot_table(heat_view_data, values='views', 
                     index=['category'], 
                     columns='country')
fig = plt.figure(figsize=(8,8)) 
ax = plt.axes()
sns.set(font_scale=1)
sns.heatmap(heat_view_data, cmap="RdBu", #annot = labels,
            ax = ax)
plt.xlabel('country', fontsize = 15) 
plt.ylabel('category', fontsize = 15)
plt.text(5, -0.5, 'Total views per country and category',
         horizontalalignment='center',
         fontsize=20)
ax.set_ylim(18.0, 0)
plt.show()

# %%
heat_view_no_gb = heat_view_data.drop([('sum', 'GB')], axis = 'columns')
fig = plt.figure(figsize=(8,8)) 
ax = plt.axes()
sns.set(font_scale=1)
sns.heatmap(heat_view_no_gb, cmap="RdBu", #annot = labels,
            ax = ax)
plt.xlabel('country', fontsize = 15) 
plt.ylabel('category', fontsize = 15)
plt.text(5, -0.5, 'Total views per country and category without GB',
         horizontalalignment='center',
         fontsize=20)
ax.set_ylim(18.0, 0)
plt.show()

# %%
def position(country, category):
    df_pos = heat_view_data
    df_pos = df_pos[('sum', country)].to_frame().reset_index()
    df_pos = df_pos.sort_values(('sum', country), ascending = False).reset_index()
    return int(df_pos[df_pos['category']== category].index.values.astype(int))+1
position('CA', 'Autos & Vehicles')
# Out:
# 12

# %%
df_grid = df
df_grid = df_grid[df_grid.country != 'GB']
labels = []
position_in_row = 0
row_list = []
for i in sorted(set(df_grid.category)):
    for b in sorted(set(df_grid.country)):
        if position_in_row < len(set(df_grid.country)):
            row_list.append(position(b, i))
            position_in_row += 1
    else: 
        labels.append(row_list)
        row_list = [] 
        position_in_row = 0
labels = np.asarray(labels)
labels
# Out:
# array([[12, 10, 12, 13, 12, 16, 11,  7, 12],
#        [ 4,  4,  3,  4,  5,  5,  5,  3,  3],
#        [11, 12, 11, 10, 14, 12, 12, 15, 11],
#        [ 1,  1,  1,  1,  1,  1,  1,  1,  1],
#        [ 8,  6,  8,  5,  6,  6,  9,  8,  5],
#        [ 9,  8,  9, 12,  8,  8,  8, 12,  9],
#        [ 7,  9,  7,  7,  9,  9,  6,  6,  6],
#        [17, 18, 17, 14, 16, 18, 17, 17, 17],
#        [ 2,  5,  4,  2,  4,  4,  2,  5,  2],
#        [ 6,  7,  6,  3,  7,  3,  7,  4, 10],
#        [16, 13, 15, 15, 15, 14, 15, 11, 15],
#        [ 3,  2,  5,  6,  2,  2,  3,  2,  7],
#        [13, 15, 14, 17, 10, 10, 13, 13, 13],
#        [10, 11, 10,  9, 11, 11, 10, 10,  8],
#        [15, 14, 13, 11, 17, 13, 16, 14, 16],
#        [ 5,  3,  2,  8,  3,  7,  4,  9,  4],
#        [18, 17, 18, 18, 18, 17, 18, 18, 18],
#        [14, 16, 16, 16, 13, 15, 14, 16, 14]])

# %%
heat_view_no_gb = heat_view_data.drop([('sum', 'GB')], axis = 'columns')
fig = plt.figure(figsize=(8,8)) 
ax = plt.axes()
sns.set(font_scale=1)
sns.heatmap(heat_view_no_gb, cmap="RdBu", annot = labels,
            ax = ax)
plt.xlabel('country', fontsize = 15) 
plt.ylabel('category', fontsize = 15)
plt.text(5, -0.5, 'Total views per country and category without GB',
         horizontalalignment='center',
         fontsize=20)
ax.set_ylim(18.0, 0)
plt.show()

# %% [markdown]
# ## Part2. User's view
# ### What to put in the user's tool bag
# In this part I'm trying to use the point of view of a YouTube user. My goal is to find some good practice to boost the probabilty for my video to be successful. At first I've found the number of tag using a function. Then I've made a barplot to visualize the mean of tag for each category.

# %%
def tag_count(tags):
    tot_tag = []
    for i in tags:
        i = i.split("|")
        tot_tag.append(i.index(i[-1])+1)
    return tot_tag

# %%
df['tags_number'] = tag_count(df[str('tags')])
tags_df = df[['video_id', 'tags_number', 'views', 'country', 'category']]
tags_df.head()
# Out:
#       video_id  tags_number   views country          category
# 0  cJon8yBKv3g           44   19487      FR  Film & Animation
# 1  g12KeCPRB4Q            9   20744      FR            Gaming
# 2  irIZRH3JlIw            8  207452      FR   News & Politics
# 3  SnHtzkQZggA           22   15899      FR  Film & Animation
# 4  u6EoWM2KMPE            6  100607      FR            Comedy

# %%
tags_df = df.groupby(['category']).agg({'tags_number': ['mean']})
tags_df = tags_df.sort_values(('tags_number', 'mean'), ascending = False)
tags_df = tags_df.reset_index()
fig = plt.figure(figsize=(8,6)) 
ax = fig.gca()
sns.barplot(x = 'category', y = ('tags_number', 'mean'), data = tags_df)
plt.xticks(rotation=90)
sns.set(font_scale=1.5)
ax.set_title('Tag mean per category')
# Out:
# Text(0.5, 1.0, 'Tag mean per category')

# %% [markdown]
# ## Number of dislike to expect from my video
# I did the same operation with the number of likes and dislakes. So that, depending on the category of my vide, I know how many likes and dislikes is reasonable to expect.

# %%
dislike_cat_df = df.groupby(['category']).agg({'dislikes': ['mean']})
dislike_cat_df = dislike_cat_df.sort_values(('dislikes', 'mean'), ascending = False)
dislike_cat_df = dislike_cat_df.reset_index()
fig = plt.figure(figsize=(8,6)) 
ax = fig.gca()
sns.barplot(x = 'category', y = ('dislikes', 'mean'), data = dislike_cat_df)
plt.xticks(rotation=90)
sns.set(font_scale=1.5)
ax.set_title('Dislike mean per category')
# Out:
# Text(0.5, 1.0, 'Dislike mean per category')

# %% [markdown]
# ## Number of like to expect from my video

# %%
like_cat_df = df.groupby(['category']).agg({'likes': ['mean']})
like_cat_df = like_cat_df.sort_values(('likes', 'mean'), ascending = False)
like_cat_df = like_cat_df.reset_index()
fig = plt.figure(figsize=(8,6)) 
ax = fig.gca()
sns.barplot(x = 'category', y = ('likes', 'mean'), data = like_cat_df)
plt.xticks(rotation=90)
sns.set(font_scale=1.5)
ax.set_title('Like mean per category')
# Out:
# Text(0.5, 1.0, 'Like mean per category')

# %% [markdown]
# ## What can I expect in terms of views?
# I've created a new variable called 'view_growth' to measure the difference, in terms of number of views, between the last collection and the first one.

# %%
df_all_timestamps['min_views'] = df_all_timestamps['views'].groupby(df_all_timestamps['video_id']).transform('min')
df_all_timestamps['max_views'] = df_all_timestamps['views'].groupby(df_all_timestamps['video_id']).transform('max')
df_all_timestamps['view_growth'] = df_all_timestamps['max_views'] - df_all_timestamps['min_views']
df_all = df_all_timestamps
#df_all = df_all_timestamps[df_all_timestamps['view_growth'] > 0]

# %%
df_all = df_all.groupby(['category']).agg({'view_growth': ['mean']})
df_all = df_all.sort_values(('view_growth', 'mean'), ascending = False)
df_all = df_all.reset_index()
fig = plt.figure(figsize=(8,6)) 
ax = fig.gca()
sns.barplot(x = 'category', y = ('view_growth', 'mean'), data = df_all, ax = ax)
plt.xticks(rotation=90)
sns.set(font_scale=1.5)
ax.set_title('Views growth mean per category')
# Out:
# Text(0.5, 1.0, 'Views growth mean per category')

# %% [markdown]
# ## A new variable 'engagement', adding up number of likes, dislikes and comment
# I've created a new variable with the purpose to quantify the relevance of the enagements, in other words the active interection from other users in relation with my video.

# %%
df['engagement'] = df['likes'] + df['dislikes'] + df['comment_count']
engage_cat_df = df.groupby(['category']).agg({'engagement': ['mean']})
engage_cat_df.head()
# Out:
#                     engagement
#                           mean
# category
# Autos & Vehicles   9130.159133
# Comedy            24188.797548
# Education          6513.106749
# Entertainment     11168.790778
# Film & Animation   8768.875887

# %%
engage_cat_df = engage_cat_df.sort_values(('engagement', 'mean'), ascending = False)
engage_cat_df = engage_cat_df.reset_index()
fig = plt.figure(figsize=(8,6)) 
ax = fig.gca()
sns.barplot(x = 'category', y = ('engagement', 'mean'), data = engage_cat_df, ax = ax)
plt.xticks(rotation=90)
sns.set(font_scale=1.5)
ax.set_title('Engagement mean per category')
# Out:
# Text(0.5, 1.0, 'Engagement mean per category')

# %% [markdown]
# ## The regression...

# %%
sns.lmplot(x = 'engagement', y = 'views', data = df, height = 10)
ax = plt.gca()
ax.set_title('Views by engagement')
# Out:
# Text(0.5, 1, 'Views by engagement')

# %% [markdown]
# ## What about countries?

# %%
sns.lmplot(x = 'engagement', y = 'views', hue = 'country', data = df, height = 10)
ax = plt.gca()
ax.set_title('Views by engagement and country')
# Out:
# Text(0.5, 1, 'Views by engagement and country')

# %% [markdown]
# ## For next analysis
# In conclusion, I can notice that there are others interesting aspects to study, like the number of comments and the publish time and date. Especially for a new user, is important to know the tendency in terms of visualizations of a specific video category. Also the description column rappresents a good variable to consider.
# What made me skeptical about this dataset was the lack of some kind of information. For example would have been useful to know the video length and the channel subscriptions.
